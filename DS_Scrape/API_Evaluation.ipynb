# %% [markdown]
# ## Read in data from the prediction file of API

# %%
import pandas as pd

# Assuming your data is in a CSV file named 'laptop_data.csv'
file_path = 'laptops_0-1499.csv'

# Read the data into a pandas DataFrame
df = pd.read_csv(file_path, nrows = 50)

# Display the DataFrame to check if it was read correctly
print(df)
# Out:
#         Brand                                                CPU  \
# 0      Lenovo            Intel Core i7 13th Gen 1355U (1.70GHz)
# 1        Acer             Intel Core i7 13th Gen 1355U (1.70GHz)
# 2         MSI                                  AMD Ryzen 5-7530U
# 3         MSI                                 i7-1280P (1.80GHz)
# 4        Acer                     Intel Celeron N4500 (1.10GHz)
# 5        Acer                     Intel Celeron N4500 (1.10GHz)
# 6         MSI          Intel Core i9 13th Gen 13950HX (2.20GHz)
# 7         MSI                                  AMD Ryzen 7-7730U
# 8        Acer             Intel Core i5 12th Gen 1235U (1.30GHz)
# 9          LG                      Intel Core i7-1260P (2.10GHz)
# 10     Lenovo            AMD Ryzen 5 5000 Series 5500U (2.10GHz)
# 11       Acer           Intel Core i5 11th Gen 1135G7 (2.40GHz)
# 12         HP             Intel Core i5 12th Gen 1235U (1.30GHz)
# ...

# %% [markdown]
# ## Read in Data from Hand-labelled File

# %%
import pandas as pd

# Assuming your data is in a CSV file named 'laptop_data.csv'
file_path = 'true_label_0-50.csv'

# Read the data into a pandas DataFrame
df = pd.read_csv(file_path, encoding = "windows-1252")

# Display the DataFrame to check if it was read correctly
print(df)
# Out:
#         Brand                             CPU                      GPU  \
# 0      Lenovo               i7 13th Gen 1355U   Intel Iris Xe Graphics
# 1        Acer               i7 13th Gen 1355U   Intel Iris Xe Graphics
# 2         MSI               AMD Ryzen 5 7530U      AMD Radeon Graphics
# 3         MSI               I7 12th Gen 1280P   Intel Iris Xe Graphics
# 4        Acer             Intel Celeron N4500       Intel UHD Graphics
# 5        Acer             Intel Celeron N4500       Intel UHD Graphics
# 6         MSI  Intel Core i9 13th Gen 13950HX      NVIDIA RTX 2000 ADA
# 7         MSI               AMD Ryzen 7 7730U      AMD Radeon Graphics
# 8        Acer    Intel Core i5 12th Gen 1235U   Intel Iris Xe Graphics
# 9          LG    Intel Core i7 12th Gen 1260P   Intel Iris Xe Graphics
# 10     Lenovo        AMD Ryzen 5 Series 5500U      AMD Radeon Graphics
# 11       Acer   Intel Core i5 11th Gen 1135G7   Intel Iris Xe Graphics
# ...
